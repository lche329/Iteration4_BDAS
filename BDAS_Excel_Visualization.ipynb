# %%
import findspark
findspark.init('/home/user/spark-2.1.1-bin-hadoop2.7')
import pyspark
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('BDAS_EXCEL').getOrCreate()
import pandas

# %%
rawdata = pandas.read_excel("./Sales_data/sales.xlsx")

# %%
print(rawdata)
# Out:
#           ID  Year     Product Name     Unit    Region Sales Representative  \
# 0          1  2016  Corbrin Capsule  Dept. 2     Wuhan                   熊婷
# 1          2  2016  Corbrin Capsule  Dept. 2     Wuhan                   熊婷
# 2          3  2016  Corbrin Capsule  Dept. 2     Wuhan                   熊婷
# 3          4  2016  Corbrin Capsule  Dept. 2     Wuhan                   熊婷
# 4          5  2016  Corbrin Capsule  Dept. 2     Wuhan                   熊婷
# 5          6  2016  Corbrin Capsule  Dept. 2     Wuhan                   熊婷
# 6          7  2016  Corbrin Capsule  Dept. 2     Wuhan                   熊婷
# 7          8  2016  Corbrin Capsule  Dept. 2     Wuhan                   熊婷
# 8          9  2016  Corbrin Capsule  Dept. 2     Wuhan                   熊婷
# 9         10  2016  Corbrin Capsule  Dept. 2     Wuhan                   熊婷
# 10        11  2016  Corbrin Capsule  Dept. 2     Wuhan                   熊婷
# ...

# %%
# Import matplotlib
import matplotlib.pyplot as plt
# Make a histogram of all the ratings in the average_rating column.
plt.xlabel('Profits')
plt.ylabel('Count')
plt.hist(rawdata['Profits'])
# Out:
# (array([3.9897e+04, 2.8300e+02, 6.1000e+01, 2.4000e+01, 9.0000e+00,
#         3.0000e+00, 4.0000e+00, 0.0000e+00, 2.0000e+00, 2.0000e+00]),
#  array([ -130.02 ,  3748.582,  7627.184, 11505.786, 15384.388, 19262.99 ,
#         23141.592, 27020.194, 30898.796, 34777.398, 38656.   ]),
#  <a list of 10 Patch objects>)

# %%
# Import matplotlib
import matplotlib.pyplot as plt
plt.xlabel('Satisfactory Level')
plt.ylabel('Count')
plt.hist(rawdata['Satisfaction'])

# %%
# Import matplotlib
import matplotlib.pyplot as plt
plt.scatter(x=rawdata['Sales Volume'],y=rawdata['Profits'])
plt.xlabel('Sales Volume')
plt.ylabel('Profits')
plt.show()

# %%
# import the seaborn module
import seaborn as sns
# import the matplotlib module
### import matplotlib.pyplot as plt

# set the background colour of the plot to white
sns.set(style="whitegrid", color_codes=True)
# setting the plot size for all plots
sns.set(rc={'figure.figsize':(11.7,8.27)})
# create a countplot
sns.countplot('Satisfaction',data=rawdata,hue = 'Product Name')
# Remove the top and down margin
sns.despine(offset=10, trim=True)

# %%
# import the seaborn module
import seaborn as sns
# import the matplotlib module
### import matplotlib.pyplot as plt

# set the background colour of the plot to white
sns.set(style="whitegrid", color_codes=True)
# setting the plot size for all plots
sns.set(rc={'figure.figsize':(11.7,8.27)})
# create a countplot
sns.countplot('Satisfaction',data=rawdata,hue = 'Region')
# Remove the top and down margin
sns.despine(offset=10, trim=True)

# %%
# import the seaborn module
import seaborn as sns
# import the matplotlib module
### import matplotlib.pyplot as plt

# set the background colour of the plot to white
sns.set(style="whitegrid", color_codes=True)
# setting the plot size for all plots
sns.set(rc={'figure.figsize':(11.7,8.27)})
# create a countplot
sns.countplot('Satisfaction',data=rawdata,hue = 'Hospital Attribute')
# Remove the top and down margin
sns.despine(offset=10, trim=True)

# %%
# import the seaborn module
import seaborn as sns
# import the matplotlib module
### import matplotlib.pyplot as plt

# set the background colour of the plot to white
sns.set(style="whitegrid", color_codes=True)
# setting the plot size for all plots
sns.set(rc={'figure.figsize':(11.7,8.27)})
# create a countplot
sns.countplot('Satisfaction',data=rawdata,hue = 'Purchasing Price')
# Remove the top and down margin
sns.despine(offset=10, trim=True)

# %%
# import the seaborn module
import seaborn as sns
# import the matplotlib module
import matplotlib.pyplot as plt
# setting the plot size for all plots
sns.set(rc={'figure.figsize':(16.7,13.27)})
# plotting the violinplot
sns.violinplot(x="Satisfaction",y="Purchasing Price", hue="Satisfaction", data=rawdata);
plt.show()

# %%
# import the seaborn module
import seaborn as sns
# import the matplotlib module
### import matplotlib.pyplot as plt

# set the background colour of the plot to white
sns.set(style="whitegrid", color_codes=True)
# setting the plot size for all plots
sns.set(rc={'figure.figsize':(11.7,8.27)})
# create a countplot
sns.countplot('Satisfaction',data=rawdata,hue = 'Selling Price')
# Remove the top and down margin
sns.despine(offset=10, trim=True)

# %%
# import the seaborn module
import seaborn as sns
# import the matplotlib module
import matplotlib.pyplot as plt
# setting the plot size for all plots
sns.set(rc={'figure.figsize':(16.7,13.27)})
# plotting the violinplot
sns.violinplot(x="Satisfaction",y="Selling Price", hue="Satisfaction", data=rawdata);
plt.show()

# %%
# import the seaborn module
import seaborn as sns
# import the matplotlib module
### import matplotlib.pyplot as plt

# set the background colour of the plot to white
sns.set(style="whitegrid", color_codes=True)
# setting the plot size for all plots
sns.set(rc={'figure.figsize':(11.7,8.27)})
# create a countplot
sns.countplot('Satisfaction',data=rawdata,hue = 'Hospital Class')
# Remove the top and down margin
sns.despine(offset=10, trim=True)

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(rawdata)
plt.show()
# Out:
# /home/user/.local/lib/python3.6/site-packages/matplotlib/axes/_base.py:3152: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=2016.0, right=2016.0
#   'left=%s, right=%s') % (left, right))
# /home/user/.local/lib/python3.6/site-packages/matplotlib/axes/_base.py:3471: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=2016.0, top=2016.0
#   'bottom=%s, top=%s') % (bottom, top))

# %%
print(rawdata.dtypes)
# Out:
# ID                        int64
# Year                      int64
# Product Name             object
# Unit                     object
# Region                   object
# Sales Representative     object
# Hospital Name            object
# Hospital Attribute       object
# Hospital Code            object
# Purchasing Price        float64
# Selling Price           float64
# IMF                      object
# Hospital Class           object
# Department               object
# Client Name              object
# Sales Volume            float64
# Profits                 float64
# Satisfaction             object
# dtype: object

# %%
(rawdata.drop(columns=['Year','ID'])).hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f09018a6eb8>,
# ...
#       dtype=object)

# %%
# import the seaborn module
import seaborn as sns
# import the matplotlib module
### import matplotlib.pyplot as plt

# set the background colour of the plot to white
sns.set(style="whitegrid", color_codes=True)
# setting the plot size for all plots
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.countplot('Satisfaction',data=rawdata,hue = 'Sales Representative')
# Remove the top and down margin
sns.despine(offset=10, trim=True)

# %%
print('Description of The Dataframe')
rawdata.describe()
# Out:
# Description of The Dataframe
#                  ID     Year  Purchasing Price  Selling Price  Sales Volume  \
# count  40285.000000  40285.0      40285.000000   40285.000000  40285.000000
# mean   20143.000000   2016.0        103.082617     123.355351     17.451654
# std    11629.422134      0.0        202.519486     227.761945     59.636557
# min        1.000000   2016.0         15.350000      23.260000    -20.000000
# 25%    10072.000000   2016.0         34.890000      35.700000      0.000000
# 50%    20143.000000   2016.0         47.140000      63.140000      3.000000
# 75%    30214.000000   2016.0         47.140000      64.300000     12.000000
# max    40285.000000   2016.0        917.620000    1047.640000   2227.000000
#
#             Profits
# count  40285.000000
# mean     234.697829
# std      914.411227
# min     -130.020000
# 25%        0.000000
# 50%       24.160000
# 75%      144.960000
# max    38656.000000

# %%
# import the seaborn module
import seaborn as sns
# import the matplotlib module
### import matplotlib.pyplot as plt

# set the background colour of the plot to white
sns.set(style="whitegrid", color_codes=True)
# setting the plot size for all plots
sns.set(rc={'figure.figsize':(11.7,8.27)})
# create a countplot
sns.countplot('Sales Volume',data=rawdata,hue = 'Product Name',order=rawdata.Profits.value_counts().iloc[:6].index)
# Remove the top and down margin
sns.despine(offset=10, trim=True)
